# %%
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('U.S._Chronic_Disease_Indicators.csv')

# %%
df.head(30)
# Out:
#     YearStart  YearEnd LocationAbbr    LocationDesc     DataSource  \
# 0        2015     2019           US   United States  US Cancer DVT
# 1        2019     2019           GU            Guam          BRFSS
# 2        2019     2019           ID           Idaho          BRFSS
# 3        2019     2019           MD        Maryland          BRFSS
# 4        2019     2019           MI        Michigan           NVSS
# 5        2019     2019           MN       Minnesota          BRFSS
# 6        2019     2019           MS     Mississippi          BRFSS
# 7        2019     2019           MO        Missouri          BRFSS
# 8        2019     2019           NE        Nebraska          BRFSS
# 9        2019     2019           NE        Nebraska           NVSS
# 10       2019     2019           NV          Nevada          YRBSS
# 11       2019     2019           NV          Nevada          BRFSS
# 12       2019     2019           NV          Nevada          BRFSS
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DataValueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'Geolocation', 'LocationID', 'TopicID', 'QuestionID', 'ResponseID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
new_df = df.drop(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Question', 'Response','DataValueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit','StratificationCategory2',
       'Stratification2', 'StratificationCategory3', 'Stratification3',
       'Geolocation', 'LocationID', 'TopicID', 'QuestionID', 'ResponseID',
       'DataValueTypeID', 'StratificationCategoryID2', 'StratificationID2',
       'StratificationCategoryID3', 'StratificationID3'], axis='columns')

# %%
new_df.head(20)
# Out:
#             Topic DataValueUnit     DataValueType  DataValue  DataValueAlt  \
# 0          Cancer        Number            Number     3009.0        3009.0
# 1        Diabetes             %  Crude Prevalence       19.3          19.3
# 2        Diabetes             %  Crude Prevalence       10.6          10.6
# 3   Mental Health             %  Crude Prevalence       12.1          12.1
# 4   Health Status         Years            Number       78.0          78.0
# 5          Asthma             %  Crude Prevalence        8.9           8.9
# 6       Arthritis             %  Crude Prevalence       49.2          49.2
# 7         Tobacco             %  Crude Prevalence       20.6          20.6
# 8        Diabetes             %  Crude Prevalence       10.9          10.9
# 9        Diabetes        Number            Number     2108.0        2108.0
# 10        Alcohol             %  Crude Prevalence       22.8          22.8
# ...

# %%
tobacco = new_df.query('Topic == "Tobacco"')

# %%
tobacco['Stratification1'].unique()
# Out:
# array(['Male', 'Female', 'Grade 12', 'Black, non-Hispanic',
#        'White, non-Hispanic', 'Hispanic', 'Grade 11', 'Grade 10',
#        'Multiracial, non-Hispanic',
#        'American Indian or Alaska Native, non-Hispanic', 'Age 45-64',
#        'Overall', 'Asian, non-Hispanic', 'Grade 9',
#        'Hawaiian or Pacific Islander, non-Hispanic', 'Age >=65',
#        'Age 18-44'], dtype=object)

# %%
tobacco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15931 entries, 7 to 310438
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Topic                      15931 non-null  object
#  1   DataValueUnit              15931 non-null  object
#  2   DataValueType              15931 non-null  object
#  3   DataValue                  9580 non-null   float64
#  4   DataValueAlt               9580 non-null   float64
#  5   DataValueFootnoteSymbol    6528 non-null   object
#  6   StratificationCategory1    15931 non-null  object
#  7   Stratification1            15931 non-null  object
#  8   StratificationCategoryID1  15931 non-null  object
#  9   StratificationID1          15931 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.3+ MB

# %%
tobacco_filtered = tobacco[tobacco['Stratification1'].isin(['Male', 'Female', 'Age 18-44', 'Age 45-64', 'Age >=65'])]

# %%
tobacco_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3740 entries, 7 to 310384
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Topic                      3740 non-null   object
#  1   DataValueUnit              3740 non-null   object
#  2   DataValueType              3740 non-null   object
#  3   DataValue                  3057 non-null   float64
#  4   DataValueAlt               3057 non-null   float64
#  5   DataValueFootnoteSymbol    699 non-null    object
#  6   StratificationCategory1    3740 non-null   object
#  7   Stratification1            3740 non-null   object
#  8   StratificationCategoryID1  3740 non-null   object
#  9   StratificationID1          3740 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 321.4+ KB

# %%
gender_grouped = tobacco_filtered.groupby('Stratification1')

# %%
print(gender_grouped)

# %%
gender_counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Stratification1'>
